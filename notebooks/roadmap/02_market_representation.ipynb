# %% [markdown]
# # 02 Market Representation
#
# DC-REIF 2.0 notebook for KMeans submarket context and market-representation status.

# %%
from pathlib import Path
import json
import pandas as pd

project_root = Path.cwd().resolve()
cluster_summary = project_root / 'outputs' / 'reports' / 'cluster_summary.json'
cluster_profiles = project_root / 'outputs' / 'tables' / 'cluster_profiles.csv'
if cluster_summary.exists() and cluster_profiles.exists():
    print(json.loads(cluster_summary.read_text(encoding='utf-8')))
    pd.read_csv(cluster_profiles).head()
else:
    print('Run scripts/run_pipeline.py first to populate market-representation outputs.')
