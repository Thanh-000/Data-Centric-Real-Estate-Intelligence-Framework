# %% [markdown]
# # 03 Valuation Core
#
# Champion-challenger valuation notebook for the frozen Linear Regression baseline and Random Forest champion.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().resolve()
model_comparison = project_root / 'outputs' / 'tables' / 'model_comparison.csv'
if model_comparison.exists():
    pd.read_csv(model_comparison)
else:
    print('Run scripts/run_pipeline.py first to generate valuation outputs.')
