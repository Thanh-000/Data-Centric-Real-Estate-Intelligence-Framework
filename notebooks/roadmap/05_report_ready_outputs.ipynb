# %% [markdown]
# # 05 Report-Ready Outputs
#
# Notebook for the canonical final-results master files and report-ready pack.

# %%
from pathlib import Path
import json
import pandas as pd

project_root = Path.cwd().resolve()
master = project_root / 'outputs' / 'reports' / 'final_results_master.json'
report_pack = project_root / 'outputs' / 'final_report_pack' / '02_results_summary_table.csv'
if master.exists() and report_pack.exists():
    print(json.loads(master.read_text(encoding='utf-8')))
    pd.read_csv(report_pack)
else:
    print('Run scripts/build_report_results.py first to generate report-ready outputs.')
